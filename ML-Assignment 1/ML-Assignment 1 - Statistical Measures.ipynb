# %%
##importing libraries 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##loading the dataset 

df=pd.read_csv("house_price.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## Q1. Perform basic EDA

# %%
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.tail()
# Out:
#                     location       size  total_sqft  bath  price  bhk  \
# 13195             Whitefield  5 Bedroom      3453.0   4.0  231.0    5
# 13196                  other      4 BHK      3600.0   5.0  400.0    4
# 13197  Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.0    2
# 13198        Padmanabhanagar      4 BHK      4689.0   4.0  488.0    4
# 13199           Doddathoguru      1 BHK       550.0   1.0   17.0    1
#
#        price_per_sqft
# 13195            6689
# 13196           11111
# 13197            5258
# 13198           10407
# 13199            3090

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        13200 non-null  object
#  1   size            13200 non-null  object
#  2   total_sqft      13200 non-null  float64
#  3   bath            13200 non-null  float64
#  4   price           13200 non-null  float64
#  5   bhk             13200 non-null  int64
#  6   price_per_sqft  13200 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 722.0+ KB

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
df.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# price_per_sqft    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1049)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price', 'bhk',
#        'price_per_sqft'],
#       dtype='object')

# %%
sns.boxplot(data = df['price_per_sqft'],color='blue')
plt.title("price_per_sqft Outliers")
plt.show()

# %% [markdown]
# ## Detect the outliers using following methods and remove it using methods like trimming / capping/ imputation using mean or median

# %% [markdown]
# ## a) Mean and Standard deviation

# %%
# For detecting outliers 

mean=df['price_per_sqft'].mean()
std=df['price_per_sqft'].std()

#now 

lower_limit= mean-3*std
upper_limit=mean+3*std


##To identify the outliers

df[(df["price_per_sqft"]<=lower_limit) | (df["price_per_sqft"]>=upper_limit)]
# Out:
#              location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345             other  3 Bedroom        11.0   3.0   74.0    3          672727
# 1106            other  5 Bedroom        24.0   2.0  150.0    5          625000
# 4044   Sarjapur  Road  4 Bedroom         1.0   4.0  120.0    4        12000000
# 4924            other      7 BHK         5.0   7.0  115.0    7         2300000
# 11447      Whitefield  4 Bedroom        60.0   4.0  218.0    4          363333

# %%
## Removing Outliers (Trimming)

df_trimmed= df[(df['price_per_sqft'] > lower_limit) & (df['price_per_sqft']< upper_limit)]

df_trimmed

## A total of 12146 rows were obtained after trimming
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
## Capping Outliers by ensuring the column values are in float
floated_df = df.copy()

floated_df['price_per_sqft']=floated_df['price_per_sqft'].astype(float)
floated_df['price_per_sqft']=floated_df['price_per_sqft'].clip(upper=upper_limit, lower=lower_limit)

floated_df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0              3699.0
# 1              4615.0
# ...

# %%
sns.boxplot(data=floated_df['price_per_sqft'])
plt.title("price_per_sqft_after capping outlier")
plt.show()

# %% [markdown]
# ## b)Percentile method

# %%
## Bounding  into its limits 
lower_limit = df['price_per_sqft'].quantile(0.01)
upper_limit = df['price_per_sqft'].quantile(0.99)
print('upper limit : ',upper_limit)
print('lower limit : ',lower_limit)
# Out:
# upper limit :  24000.0
# lower limit :  2532.0

# %%
sns.boxplot(x = df['price_per_sqft'],color='red').set_title('price_per_sqft Outlier')
plt.show()

# %%
## for identifying the outliers 
df[(df['price_per_sqft'] >= upper_limit) | (df['price_per_sqft'] <= lower_limit)]
# Out:
#               location        size  total_sqft  bath   price  bhk  \
# 9                other   6 Bedroom      1020.0   6.0   370.0    6
# 20             Kengeri       1 BHK       600.0   1.0    15.0    1
# 45          HSR Layout   8 Bedroom       600.0   9.0   200.0    8
# 130    Electronic City       2 BHK       880.0   1.0    16.5    2
# 169           Attibele       1 BHK       450.0   1.0    11.0    1
# ...                ...         ...         ...   ...     ...  ...
# 12948            other  10 Bedroom      7150.0  13.0  3600.0   10
# 13013            other   4 Bedroom      1200.0   5.0   350.0    4
# 13078            other   4 Bedroom      9200.0   4.0  2600.0    4
# 13081            other   6 Bedroom      8000.0   6.0  2800.0    6
# 13185         Hulimavu       1 BHK       500.0   1.0   220.0    1
#
#        price_per_sqft
# 9               36274
# 20               2500
# 45              33333
# 130              1875
# 169              2444
# ...               ...
# ...

# %%
## Removing Outliers (Trimming)

trimmed_df=df[(df['price_per_sqft'] >= lower_limit) &(df['price_per_sqft'] <= upper_limit) ] 
trimmed_df

# A total of 11908 rows were obtained after trimmimg
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# capping 

float_df=df.copy()
float_df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
# Ensure the column is float before capping
float_df['price_per_sqft']=float_df['price_per_sqft'].astype(float)
float_df['price_per_sqft']=float_df['price_per_sqft'].clip(upper=upper_limit , lower=lower_limit)
float_df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0              3699.0
# 1              4615.0
# ...

# %%
sns.boxplot(x = float_df['price_per_sqft'],color ='green')
plt.title ('price_per_sqft Outlier')
plt.show()

# %% [markdown]
# ## IQR(Inter quartile range method)

# %%
# Treating the Outlier using IQR

Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)

print('Q1 : ',Q1)
print('Q3 : ',Q3)
# Out:
# Q1 :  4312.0
# Q3 :  7461.0

# %%
# Calculate the quartiles and IQR for the outlier columns
IQR = Q3 - Q1
print('IQR : ',IQR)
# Out:
# IQR :  3149.0

# %%
# Outlier treatment using IQR method (capping at 1.5 times IQR)
outliers_lower = df['price_per_sqft'] < (Q1 - 1.5 * IQR)
outliers_upper = df['price_per_sqft'] > (Q3 + 1.5 * IQR)

# %%
## to identify the outlier 

df[(df['price_per_sqft']<lower_limit ) | (df['price_per_sqft']>upper_limit )]
# Out:
#               location        size  total_sqft  bath   price  bhk  \
# 9                other   6 Bedroom      1020.0   6.0   370.0    6
# 20             Kengeri       1 BHK       600.0   1.0    15.0    1
# 45          HSR Layout   8 Bedroom       600.0   9.0   200.0    8
# 130    Electronic City       2 BHK       880.0   1.0    16.5    2
# 169           Attibele       1 BHK       450.0   1.0    11.0    1
# ...                ...         ...         ...   ...     ...  ...
# 12948            other  10 Bedroom      7150.0  13.0  3600.0   10
# 13013            other   4 Bedroom      1200.0   5.0   350.0    4
# 13078            other   4 Bedroom      9200.0   4.0  2600.0    4
# 13081            other   6 Bedroom      8000.0   6.0  2800.0    6
# 13185         Hulimavu       1 BHK       500.0   1.0   220.0    1
#
#        price_per_sqft
# 9               36274
# 20               2500
# 45              33333
# 130              1875
# 169              2444
# ...               ...
# ...

# %%
# Trimming - delete the outlier data

trimmed_df=df[(df['price_per_sqft']>lower_limit) & (df['price_per_sqft']<upper_limit)]    
trimmed_df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
sns.boxplot(data = df['price_per_sqft'],color='green')
plt.title ('price_per_sqft Outlier')
plt.show()

# %%
# capping 
float_df=df.copy()
float_df.head()

# Ensure the column is float before capping
float_df['price_per_sqft'] = float_df['price_per_sqft'].astype(float)

# Capping  the outliers to 1.5 times IQR
float_df['price_per_sqft'] = float_df['price_per_sqft'].clip(lower=Q1 - 1.5 * IQR, upper=Q3 + 1.5 * IQR)

# %%
sns.boxplot(data=float_df['price_per_sqft'],color='green')
plt.title (('price_per_sqft Outlier'))
plt.show()

# %% [markdown]
# ## Z Score method

# %%
from scipy.stats import zscore, skew, normaltest,kurtosis

# %%
#calculating z score 

z_scores= zscore(df["price_per_sqft"])
z_scores
# Out:
# array([-0.03986073, -0.03162541, -0.03441247, ...,  0.02677698,
#        -0.02584451,  0.02044765])

# %%
 # capping the outliers at +-3 standard deviation
df['price_per_sqft'] = np.where(np.abs(z_scores)>3, df['price_per_sqft'].mean(),df['price_per_sqft'])

# %%
sns.boxplot(x = df['price_per_sqft'],color='green')
plt.title('price_per_sqft Outlier')
plt.show()

# %%
# Testing for skewness

print("skewness before transformation")
print("skewness :  ",df['price_per_sqft'].skew())
# Out:
# skewness before transformation
# skewness :   10.524138142812193

# %%
# Applying log transformation to remove skewness
df['price_per_sqft'] = np.log1p(df['price_per_sqft'])

# %%
# Testing for skewness after transformation
print('Skewness After Transformation')
print("Skewness :   ",df['price_per_sqft'].skew())
# Out:
# Skewness After Transformation
# Skewness :    0.8476770312265307

# %%
sns.boxplot(x = df['price_per_sqft'],color='yellow')
plt.title('price_per_sqft Outlier')
plt.show()

# %% [markdown]
# ### Draw histplot to check the normality of the column(price per sqft column) and perform transformations if needed. Check the skewness and kurtosis before and after the transformation.

# %%
sns.histplot(data=df["price_per_sqft"],kde= True,color="skyblue")
plt.title("Original_price_per_sqft")
plt.show()

# %%
## Skewness and Kurtosis before Transmission 

real_skew= skew(df["price_per_sqft"])
real_kurtosis= kurtosis(df["price_per_sqft"])

print (f"before_ Skew :  {real_skew:3f}")
print (f"before_ kurtosis :  {real_kurtosis:3f}")
# Out:
# before_ Skew :  0.847572
# before_ kurtosis :  1.852634

# %%
#log Transformation 


df['log_price']=np.log1p(df["price_per_sqft"])

# %%
# Visualising thre plot

sns.histplot(data=df["log_price"],kde=True, color= "red")
plt.title ("Log transformed Price_per_sqft")
plt.show()

# %%
## skewness and kurtosis after log transformed  Price_per_sqft

log_skew=skew(df["log_price"])
log_kurtosis=kurtosis(df["log_price"])

print (f"after_skew:      {log_skew:.3f}")
print (f"after_kurtosis:      {log_kurtosis:.3f}")
# Out:
# after_skew:      0.609
# after_kurtosis:      1.779

# %% [markdown]
# ## Check the correlation between all the numerical columns and plot heatmap.

# %%
# To check the correlation between all the numerical columns  impute correlation matrix


correlation_matrix=df.corr(numeric_only = True)
correlation_matrix
# Out:
#                 total_sqft      bath     price       bhk  price_per_sqft  \
# total_sqft        1.000000  0.386694  0.572516  0.339936        0.108049
# bath              0.386694  1.000000  0.448802  0.898875        0.431352
# price             0.572516  0.448802  1.000000  0.390008        0.596871
# bhk               0.339936  0.898875  0.390008  1.000000        0.410643
# price_per_sqft    0.108049  0.431352  0.596871  0.410643        1.000000
# log_price         0.094230  0.426751  0.584996  0.404915        0.999025
#
#                 log_price
# total_sqft       0.094230
# bath             0.426751
# price            0.584996
# bhk              0.404915
# price_per_sqft   0.999025
# log_price        1.000000

# %%
## To Plot the heatmap 

sns.heatmap(data=correlation_matrix,annot=True , cmap = "coolwarm", fmt=".2f",linewidths=3.0)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ## Draw Scatter plot between the variables to check the correlation between them.

# %%
# Defining pairs of columns to compare
scatter_pairs = [
    ('total_sqft', 'price'),
    ('bath', 'price'),
    ('price_per_sqft', 'price')
]

# Plot each scatter plot
plt.figure(figsize=(15, 4))
for index, (x, y) in enumerate(scatter_pairs):
    plt.subplot(1, 3, index + 1)
    sns.scatterplot(data=df, x=x, y=y, alpha=0.6)
    plt.title(f'{x} vs {y}')

plt.show()
